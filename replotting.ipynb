# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
no_tail_true = pd.read_csv("wandb_csvs/wandb_export_2025-08-01T13_52_32.740-04_00.csv")
no_tail_false = pd.read_csv("wandb_csvs/wandb_export_2025-08-01T13_53_00.275-04_00_false.csv")

# %%
no_tail_true
# Out:
#      Step  \
# 0       4
# 1       8
# 2      12
# 3      16
# 4      20
# ..    ...
# 136   548
# 137   552
# 138   556
# 139   560
# 140   564
#
#      ddpo_trainer_config.train_learning_rate: 0.00005 - head_validation/reward_mean  \
# 0                                             0.153679
# 1                                             0.216334
# 2                                             0.168359
# 3                                             0.234044
# 4                                             0.205727
# ..                                                 ...
# 136                                           1.525083
# 137                                           1.539568
# 138                                           1.531334
# 139                                           1.528619
# 140                                           1.535073
#
#      ddpo_trainer_config.train_learning_rate: 0.00005 - head_validation/reward_mean__MIN  \
# ...

# %%
no_tail_false
# Out:
#      Step  \
# 0       4
# 1       8
# 2      12
# 3      16
# 4      20
# ..    ...
# 135   544
# 136   548
# 137   552
# 138   556
# 139   560
#
#      ddpo_trainer_config.train_learning_rate: 0.00005 - head_validation/reward_mean  \
# 0                                             0.119191
# 1                                             0.183706
# 2                                             0.145211
# 3                                             0.169489
# 4                                             0.160949
# ..                                                 ...
# 135                                           1.284287
# 136                                           1.319441
# 137                                           1.292208
# 138                                           1.297188
# 139                                           1.372118
#
#      ddpo_trainer_config.train_learning_rate: 0.00005 - head_validation/reward_mean__MIN  \
# ...

# %%
offwhite = "#F7F6F2"
plt.figure(facecolor="#F7F6F2")

fig, ax = plt.subplots()
fig.patch.set_facecolor("#F7F6F2")
ax.plot(no_tail_true["Step"], no_tail_true["ddpo_trainer_config.train_learning_rate: 0.00005 - head_validation/reward_mean"], label="Top 10% Classes Only", color="#203A63")
ax.plot(no_tail_false["Step"], no_tail_false["ddpo_trainer_config.train_learning_rate: 0.00005 - head_validation/reward_mean"], label="Top 10% + Bottom 10%", color="#C94C4C")
ax.legend(frameon=False)
plt.title("ImageReward - ImageNet Top 10%")
ax.set_facecolor(offwhite)
ax.tick_params(colors="#333333")
ax.xaxis.label.set_color("#333333")
ax.yaxis.label.set_color("#333333")
ax.set_xlabel("Step")
ax.set_ylabel("Reward")
# Out:
# Text(0, 0.5, 'Reward')
